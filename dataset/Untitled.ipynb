# %%
import json
from datetime import date, timedelta
import datetime
from sqlite3 import Time, Timestamp


import json
import pandas as pd
from collections import defaultdict

data = pd.read_csv('../data/train.csv')
Total_distance={}
List_of_trains = data["Train No"].unique()
Accepted_trains = [ ]
for i in List_of_trains:
    try:
        Total_distance=max(list(map(int,list(data[data["Train No"]==i]["Distance"]))))
        if(Total_distance>200):
            Accepted_trains.append(i)
    except:
        pass
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,2,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES (11017,'Chalukya Express',1000,175,'DR','YPR');
# INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES (11019,'Konark Express',1000,300,'CSTM','BBS');
# INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES (11020,'Konark Express',1000,300,'BBS','CSTM');
# INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES (11023,'Sahyadri Express',1000,95,'CSTM','KOP');
# INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES (11024,'Sahyadri Express',1000,95,'KOP','CSTM');
# ...

# %%
len(Accepted_trains)
# Out:
# 3474

# %%
with open("trainload.sql","w") as f:
    for i in range(len(train['features'])):
        if(train['features'][i]['properties']['number'] in Accepted_trains):
        
            f.write("INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES ({},'{}',{},{},'{}','{}');".format(train['features'][i]['properties']['number'],train['features'][i]['properties']['name'],1000,len(train['features'][i]['geometry']['coordinates']),train['features'][i]['properties']['from_station_code'],train['features'][i]['properties']['to_station_code']))

# %%
x=pd.read_csv('../data/train.csv')
# Out:
# C:\Users\mohit\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,2,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
x=x.drop('Departure Time',axis=1)
x=x.drop('Arrival time',axis=1)
x=x.drop('Station Code',axis=1)
x=x.drop('Source Station Name',axis=1)
x=x.drop('Destination Station Name',axis=1)
x=x.drop('SEQ',axis=1)
x=x.drop('Distance',axis=1)
x=x.drop('Station Name',axis=1)

# %%
x=x.drop_duplicates()

# %%
x
# Out:
#        Train No    Train Name Source Station Destination Station
# 0           107  SWV-MAO-VLNK            SWV                 MAO
# 4           108  VLNK-MAO-SWV            MAO                 SWV
# 8           128  MAO-KOP SPEC            MAO                 KOP
# 30          290  PALACE ON WH            DSJ                 DSJ
# 44          401  BSB BHARATDA            AWB                 BSB
# ...         ...           ...            ...                 ...
# 186065    99904  PUNE-TGN EMU           PUNE                 TGN
# 186077    99905           EMU            TGN                SVJR
# 186088    99906           EMU           PUNE                 TGN
# 186100    99907           EMU            TGN                PUNE
# 186112    99908           EMU           PUNE                 TGN
#
# [11124 rows x 4 columns]

# %%
with open("trainload.sql","w") as f:
    for i in x.iterrows():
        if(i[1]['Train No'] in Accepted_trains):
            f.write("INSERT INTO train(train_no,train_name,capacity,num_stations,source_id,dest_id) VALUES ({},'{}',{},{},'{}','{}');\n".format(i[1]['Train No'],i[1]['Train Name'],1000,L[i[1]['Train No']],i[1]['Source Station'],i[1]['Destination Station']))

# %%
for i in x.iterrows():
    print(i)
    break
# Out:
# (0, Train No                                107
# Train Name                     SWV-MAO-VLNK
# SEQ                                       1
# Station Code                            SWV
# Station Name                   SAWANTWADI R
# Arrival time                       00:00:00
# Departure Time                     10:25:00
# Distance                                  0
# Source Station                          SWV
# Source Station Name         SAWANTWADI ROAD
# Destination Station                     MAO
# Destination Station Name        MADGOAN JN.
# Name: 0, dtype: object)

# %%
def f(p):
    global x
    return len(x[x["Train No"]==p])
x["num_station"] = x["Train No"].apply(f)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-ea74ee9354c3> in <module>
#       2     global x
#       3     return len(x[x["Train No"]==p])
# ----> 4 x["num_station"] = x["Train No"].apply(f)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# -> 4138                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4139
#    4140         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-11-ea74ee9354c3> in f(p)
#       1 def f(p):
#       2     global x
# ----> 3     return len(x[x["Train No"]==p])
#       4 x["num_station"] = x["Train No"].apply(f)
#
# ...

# %%
L=x['Train No'].value_counts()

# %%
x['Train No'].value_counts()['107']
# Out:
# 4

# %%
x.drop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Train No', 'Train Name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-405e077a03b6> in <module>
# ...

# %%
A=x['Station Code'].unique()

# %%
import json

text_file = open("stations.json", "r")
data = text_file.read()
text_file.close()
data  = json.loads(data)
B=[]

for i in range(len(data['features'])):
    B.append(data['features'][i]['properties']['code'])

# %%
g=0
for i in A:
    if(i not in B):
        g+=1

# %%
x
# Out:
#        Train No    Train Name SEQ Station Code  Station Name Arrival time  \
# 0           107  SWV-MAO-VLNK   1          SWV  SAWANTWADI R     00:00:00
# 1           107  SWV-MAO-VLNK   2         THVM        THIVIM     11:06:00
# 2           107  SWV-MAO-VLNK   3         KRMI       KARMALI     11:28:00
# 3           107  SWV-MAO-VLNK   4          MAO   MADGOAN JN.     12:10:00
# 4           108  VLNK-MAO-SWV   1          MAO   MADGOAN JN.     00:00:00
# ...         ...           ...  ..          ...           ...          ...
# 186119    99908           EMU   8         AKRD        AKURDI     23:30:00
# 186120    99908           EMU   9         DEHR     DEHU ROAD     23:35:00
# 186121    99908           EMU  10         BGWI     BEGDAEWAI     23:39:00
# 186122    99908           EMU  11         GRWD     GHORAWADI     23:41:00
# 186123    99908           EMU  12          TGN      TALEGAON     23:50:00
#
#        Departure Time Distance Source Station Source Station Name  \
# ...

# %%
def fg(x):
    global B
    if(x not in B):
        return False
x['new']=x['Station Code'].map(fg)

# %%
len(x[x['new']==False])
# Out:
# 5850

# %%
f=x[x['new']==False]

# %%
len(f['Train No'].unique())
# Out:
# 2095

# %%
g
# Out:
# 471
